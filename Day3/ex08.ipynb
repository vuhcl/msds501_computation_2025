# %%
from PIL import Image
img = Image.open("../Data/image.jpeg").convert("L") # convert to black and white

width, height = img.size
pixel_list = list()
# Iterate through pixels using nested loops
for y in range(height):
    pixel_row = list()
    for x in range(width):
        pixel_value = 255 - img.getpixel((x, y))
        pixel_row.append(pixel_value)
    pixel_list.append(pixel_row)

# %%
inverted_img = Image.new("L", (width, height))
for y in range(height):
    for x in range(width):
        inverted_img.putpixel((x, y), pixel_list[y][x])

# %%
img
# Out:
# <PIL.Image.Image image mode=L size=258x195>

# %%
inverted_img
# Out:
# <PIL.Image.Image image mode=L size=258x195>
